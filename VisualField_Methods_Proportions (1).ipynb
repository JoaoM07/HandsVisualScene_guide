# %% [markdown]
# #In this notebook, we have calculated hand proportions irrespective of hand side, by hand side and by hand dominance.
#
# ##We have used the file paths from the previous notebook, VisualField_Methods0. You will need to change the file path if you have saved the csv files in a different folder. Or if you have exported this notebook as a jupyter notebook, you will need to access the csv files from your hard drive.
# \

# %%
#importing pandas library and accessing google drive

import pandas as pd

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #Hand location irrespective of handedness
#
# ##Descriptive statistics

# %%
#Loads the overall data (change file path to your own file path)
overall_df = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/Final_Big_frame.csv')

#Prints the first five rows
overall_df.head()
# Out:
#   Participant   Frame   Hand  cart_Centre_Y   Centre_X            Contact
# 0  P01_01.pkl     211  right          108.5      321.0  STATIONARY_OBJECT
# 1  P01_01.pkl     212  right          114.5      324.5  STATIONARY_OBJECT
# 2  P01_01.pkl     213  right          130.0      328.5    PORTABLE_OBJECT
# 3  P01_01.pkl     214  right          134.0      329.0    PORTABLE_OBJECT
# 4  P01_01.pkl     215  right          137.5      326.5    PORTABLE_OBJECT

# %% [markdown]
# #Hand location in the visual field (proportions)
# ##Irrespective of handedness
# \

# %%
#dataframe for hand location in the visual space 
dfH = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/hands_dataset_analysis.csv')
dfH
# Out:
#    hands_total   hands_left   left_upper   left_lower   left_ipsi  \
# 0     31300201     15176277      3250461     11925816    12786258
#
#     left_contra   left_ULquad   left_LLquad   leftURquad   leftLRquad  \
# 0       2390019       2781452      10004806       469009      1921010
#
#     hands_right   right_upper   right_lower   right_contra   right_ipsi  \
# 0      16123924       4277873      11846051        1487604     14636320
#
#     right_ULquad   right_LLquad   right_URquad   right_LRquad
# 0         338845        1148759        3939028       10697292

# %%
#Proportion of hands in the upper visual field (UVF)
((dfH[' left_upper'] + dfH[' right_upper']) / dfH['hands_total']) * 100
# Out:
# 0    24.052031
# dtype: float64

# %%
#Proportion of hands in the lower visual field (LVF)
((dfH[' left_lower'] + dfH[' right_lower']) / dfH['hands_total']) * 100
# Out:
# 0    75.947969
# dtype: float64

# %%
#Proportion of hands in the ipsilateral visual field
((dfH[' left_ipsi'] + dfH[' right_ipsi']) / dfH['hands_total']) * 100
# Out:
# 0    87.611508
# dtype: float64

# %%
#Proportion of hands in the contralateral visual field
((dfH[' left_contra'] + dfH[' right_contra']) / dfH['hands_total']) * 100
# Out:
# 0    12.388492
# dtype: float64

# %%
#Proportion of hands in the upper left quadrant
((dfH[' left_ULquad'] + dfH[' right_ULquad']) / dfH['hands_total']) * 100
# Out:
# 0    9.968936
# dtype: float64

# %%
#Proportion of hands in the lower left quadrant
((dfH[' left_LLquad'] + dfH[' right_LLquad']) / dfH['hands_total']) * 100
# Out:
# 0    35.634164
# dtype: float64

# %%
#Proportion of hands in the upper right quadrant
((dfH[' leftURquad'] + dfH[' right_URquad']) / dfH['hands_total']) * 100
# Out:
# 0    14.083095
# dtype: float64

# %%
#Proportion of hands in the lower right quadrant
((dfH[' leftLRquad'] + dfH[' right_LRquad']) / dfH['hands_total']) * 100
# Out:
# 0    40.313805
# dtype: float64

# %% [markdown]
# #Left hand location in the visual field

# %%
#Proportion of left hands in the UVF
(dfH[' left_upper'] / dfH[' hands_left']) * 100
# Out:
# 0    21.418039
# dtype: float64

# %%
#Proportion of left hands in the LVF
(dfH[' left_lower'] / dfH[' hands_left']) * 100
# Out:
# 0    78.581961
# dtype: float64

# %%
#Proportion of left hands in the ipsilateral field
(dfH[' left_ipsi'] / dfH[' hands_left']) * 100
# Out:
# 0    84.251612
# dtype: float64

# %%
#Proportion of left hands in the contralateral field
(dfH[' left_contra'] / dfH[' hands_left']) * 100
# Out:
# 0    15.748388
# dtype: float64

# %%
#Proportion of left hands in the upper left quadrant
(dfH[' left_ULquad'] / dfH[' hands_left']) * 100
# Out:
# 0    18.327631
# dtype: float64

# %%
#Proportion of left hands in the lower left quadrant
(dfH[' left_LLquad'] / dfH[' hands_left']) * 100
# Out:
# 0    65.923981
# dtype: float64

# %%
#Proportion of left hands in the upper right quadrant
(dfH[' leftURquad'] / dfH[' hands_left']) * 100
# Out:
# 0    3.090409
# dtype: float64

# %%
#Proportion of left hands in the lower right quadrant
(dfH[' leftLRquad'] / dfH[' hands_left']) * 100
# Out:
# 0    12.657979
# dtype: float64

# %% [markdown]
# #Right hand location
# \

# %%
#Proportion of right hands in the UVF
(dfH[' right_upper'] / dfH[' hands_right']) * 100
# Out:
# 0    26.531215
# dtype: float64

# %%
#Proportion of right hands in the LVF
(dfH[' right_lower'] / dfH[' hands_right']) * 100
# Out:
# 0    73.468785
# dtype: float64

# %%
#Proportion of right hands in the ipsilateral field
(dfH[' right_ipsi'] / dfH[' hands_right']) * 100
# Out:
# 0    90.773933
# dtype: float64

# %%
#Proportion of right hands in the contralateral field
(dfH[' right_contra'] / dfH[' hands_right']) * 100
# Out:
# 0    9.226067
# dtype: float64

# %%
#Proportion of right hands in the upper left quadrant
(dfH[' right_ULquad'] / dfH[' hands_right']) * 100
# Out:
# 0    2.101505
# dtype: float64

# %%
#Proportion of right hands in the lower left quadrant
(dfH[' right_LLquad'] / dfH[' hands_right']) * 100
# Out:
# 0    7.124562
# dtype: float64

# %%
#Proportion of right hands in the upper right quadrant
(dfH[' right_URquad'] / dfH[' hands_right']) * 100
# Out:
# 0    24.429711
# dtype: float64

# %%
#Proportion of right hands in the lower right quadrant
(dfH[' right_LRquad'] / dfH[' hands_right']) * 100
# Out:
# 0    66.344222
# dtype: float64

# %%
print('Total number of left hand frames = ' + str(dfH[' hands_left'].sum()))
# Out:
# Total number of left hand frames = 15176277

# %%
print('Total number of right hand frames = ' + str(dfH[' hands_right'].sum()))
# Out:
# Total number of right hand frames = 16123924

# %% [markdown]
# #Hand-Object Interaction (proportions)
# ##No object interaction

# %%
#Loading the respective csv file
dfNo = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/hands_noContact_analysis.csv')
dfNo
# Out:
#    hands_total   noContact_total   noContact_left   noContact_left_upper  \
# 0     31300201           3968863          2091966                 287840
#
#     noContact_left_lower   noContact_left_ipsi   noContact_left_contra  \
# 0                1804126               1751737                  340229
#
#     noContact_left_ULquad   noContact_left_LLquad   noContact_left_URquad  \
# 0                  241528                 1510209                   46312
#
#     noContact_left_LRquad   noContact_hands_right   noContact_right_upper  \
# 0                  293917                 1876897                  388153
#
#     noContact_right_lower   noContact_right_contra   noContact_right_ipsi  \
# 0                 1488744                   241505                1635392
#
#     noContact_right_ULquad   noContact_right_LLquad   noContact_right_URquad  \
# 0                    44811                   196694                   343342
#
#     noContact_right_LRquad
# 0                  1292050

# %% [markdown]
# ##No object interaction - Irrespective of hand side

# %%
#Proportion of hands during no contact
(dfNo[' noContact_total'].sum() / dfNo['hands_total'].sum()) * 100
# Out:
# 12.679992055003098

# %%
#Proportion of hands in the UVF during no contact
((dfNo[' noContact_left_upper'].sum() + dfNo[' noContact_right_upper'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 17.03240953391437

# %%
#Proportion of hands in the LVF during no contact
((dfNo[' noContact_left_lower'].sum() + dfNo[' noContact_right_lower'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 82.96759046608562

# %%
#Proportion of hands in the ipsilateral field during no contact
((dfNo[' noContact_left_ipsi'].sum() + dfNo[' noContact_right_ipsi'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 85.34255276637163

# %%
#Proportion of hands in the contralateral field during no contact
((dfNo[' noContact_left_contra'].sum() + dfNo[' noContact_right_contra'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 14.657447233628371

# %%
#Proportion of hands in the upper left quadrant during no contact
((dfNo[' noContact_left_ULquad'].sum() + dfNo[' noContact_right_ULquad'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 7.214635526597919

# %%
#Proportion of hands in the lower left quadrant during no contact
((dfNo[' noContact_left_LLquad'].sum() + dfNo[' noContact_right_LLquad'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 43.007355003183534

# %%
#Proportion of hands in the upper right quadrant during no contact
((dfNo[' noContact_left_URquad'].sum() + dfNo[' noContact_right_URquad'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 9.817774007316453

# %%
#Proportion of hands in the lower right quadrant during no contact
((dfNo[' noContact_left_LRquad'].sum() + dfNo[' noContact_right_LRquad'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 39.96023546290209

# %% [markdown]
# ##No object interaction - Left hand

# %%
#Proportion of left hands in the UVF during no contact
(dfNo[' noContact_left_upper'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 13.759305839578657

# %%
#Proportion of left hands in the LVF during no contact
(dfNo[' noContact_left_lower'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 86.24069416042136

# %%
#Proportion of left hands in the ipsilateral field during no contact
(dfNo[' noContact_left_ipsi'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 83.73639915753888

# %%
#Proportion of left hands in the contalateral field during no contact
(dfNo[' noContact_left_contra'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 16.26360084246111

# %%
#Proportion of left hands in the upper left quadrant during no contact
(dfNo[' noContact_left_ULquad'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 11.545503129591971

# %%
#Proportion of left hands in the lower left quadrant during no contact
(dfNo[' noContact_left_LLquad'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 72.19089602794692

# %%
#Proportion of left hands in the upper right quadrant during no contact
(dfNo[' noContact_left_URquad'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 2.2138027099866826

# %%
#Proportion of left hands in the lower right quadrant during no contact
(dfNo[' noContact_left_LRquad'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 14.049798132474429

# %% [markdown]
# ##No object interaction - Right hand

# %%
#Proportion of right hands in the UVF during no contact
(dfNo[' noContact_right_upper'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 20.680570111199494

# %%
#Proportion of right hands in the LVF durng no contact
(dfNo[' noContact_right_lower'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 79.31942988880051

# %%
#Proportion of right hands in the ipsilateral field during no contact
(dfNo[' noContact_right_ipsi'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 87.1327515574909

# %%
#Proportion of right hands in the contralateral field during no contact
(dfNo[' noContact_right_contra'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 12.8672484425091

# %%
#Proportion of right hands in the upper left quadrant during no contact
(dfNo[' noContact_right_ULquad'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 2.3875044821319444

# %%
#Proportion of right hands in the lower left quadrant during no contact
(dfNo[' noContact_right_LLquad'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 10.479743960377155

# %%
#Proportion of right hands in the upper right quadrant during no contact
(dfNo[' noContact_right_URquad'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 18.293065629067552

# %%
#Proportion of right hands in the lower right quadrant during no contact
(dfNo[' noContact_right_LRquad'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 68.83968592842335

# %% [markdown]
# ##Portable objects - Irrespective of hand side

# %%
#Loading the respective csv file
dfPo = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/obj_interaction_Portable.csv')
dfPo
# Out:
#    hands_total   portable_total   portable_left   portable_left_upper  \
# 0     31300201         26054826        12463499               2818554
#
#     portable_left_lower   portable_left_ipsi   portable_left_contra  \
# 0               9644945             10551591                1911908
#
#     portable_left_ULquad   portable_left_LLquad   portable_left_URquad  \
# 0                2422196                8129395                 396358
#
#     portable_left_LRquad   portable_hands_right   portablet_right_upper  \
# 0                1515550               13591327                 3698215
#
#     portable_right_lower   portable_right_contra   portable_right_ipsi  \
# 0                9893112                 1143240              12448087
#
#     portable_right_ULquad   portable_right_LLquad   portable_right_URquad  \
# 0                  267460                  875780                 3430755
#
#     portable_right_LRquad
# 0                 9017332

# %%
#Proportion of hands during dynamic manual object interaction
(dfPo[' portable_total'].sum() / dfPo['hands_total'].sum()) * 100
# Out:
# 83.24172103559336

# %%
#Proportion of hands in the UVF during dynamic object interaction
((dfPo[' portable_left_upper'].sum() + dfPo[' portablet_right_upper'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 25.011754060456976

# %%
#Proportion of hands in the LVF during dynamic object interaction
((dfPo[' portable_left_lower'].sum() + dfPo[' portable_right_lower'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 74.98824593954302

# %%
#Proportion of hands in the ipsilateral field during dynamic object interaction
((dfPo[' portable_left_ipsi'].sum() + dfPo[' portable_right_ipsi'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 88.27415696424148

# %%
#Proportion of hands in the contralateral field during dynamic object interaction
((dfPo[' portable_left_contra'].sum() + dfPo[' portable_right_contra'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 11.725843035758519

# %%
#Proportion of hands in the upper left quadrant during dynamic object interaction
((dfPo[' portable_left_ULquad'].sum() + dfPo[' portable_right_ULquad'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 10.323062606520574

# %%
#Proportion of hands in the lower left quadrant during dynamic object interaction
((dfPo[' portable_left_LLquad'].sum() + dfPo[' portable_right_LLquad'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 34.56240697980482

# %%
#Proportion of hands in the upper right quadrant during dynamic object interaction
((dfPo[' portable_left_URquad'].sum() + dfPo[' portable_right_URquad'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 14.688691453936404

# %%
#Proportion of hands in the lower right quadrant during dynamic object interaction
((dfPo[' portable_left_LRquad'].sum() + dfPo[' portable_right_LRquad'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 40.42583895973821

# %% [markdown]
# ##Portable objects - Left Hand

# %%
#Proportion of left hands in the UVF during dynamic object interaction
(dfPo[' portable_left_upper'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 22.614468055880614

# %%
#Proportion of left hands in the LVF during dynamic object interaction
(dfPo[' portable_left_lower'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 77.38553194411938

# %%
#Proportion of left hands in the ipsilateral field during dynamic object interaction
(dfPo[' portable_left_ipsi'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 84.65994180285969

# %%
#Proportion of left hands in the contralateral field during dynamic object interaction
(dfPo[' portable_left_contra'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 15.340058197140305

# %%
#Proportion of left hands in the upper left quadrant during dynamic object interaction
(dfPo[' portable_left_ULquad'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 19.43431776261225

# %%
#Proportion of left hands in the lower left quadrant during dynamic object interaction
(dfPo[' portable_left_LLquad'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 65.22562404024744

# %%
#Proportion of left hands in the upper right quadrant during dynamic object interaction
(dfPo[' portable_left_URquad'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 3.1801502932683667

# %%
#Proportion of left hands in the lower right quadrant during dynamic object interaction
(dfPo[' portable_left_LRquad'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 12.15990790387194

# %% [markdown]
# ##Portable objects - Right hand

# %%
#Proportion of right hands in the UVF during dynamic object interaction
(dfPo[' portablet_right_upper'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 27.210109800168887

# %%
#Proportion of right hands in the LVF during dynamic object interaction
(dfPo[' portable_right_lower'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 72.7898901998311

# %%
#Proportion of right hands in the ipsilateral field during dynamic object interaction
(dfPo[' portable_right_ipsi'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 91.58845931673926

# %%
#Proportion of right hands in the contralateral field during dynamic object interaction 
(dfPo[' portable_right_contra'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 8.411540683260728

# %%
#Proportion of right hands in the upper left quadrant during dynamic object interaction
(dfPo[' portable_right_ULquad'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 1.9678725999308235

# %%
#Proportion of right hands in the lower left quadrant during dynamic object interaction
(dfPo[' portable_right_LLquad'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 6.443668083329906

# %%
#Proportion of right hands in the upper right quadrant during dynamic object interaction
(dfPo[' portable_right_URquad'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 25.242237200238065

# %%
#Proportion of right hands in the lower right quadrant during dynamic object interaction
(dfPo[' portable_right_LRquad'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 66.34622211650121

# %% [markdown]
# ##Stationary objects - Irrespective of hand side

# %%
#Loading the respective csv file
dfSt = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/obj_interaction_Stationary.csv')
dfSt
# Out:
#    hands_total   Stationary_total   Stationary_left   Stationary_left_upper  \
# 0     31300201             901915            427683                  106388
#
#     Stationary_left_lower   Stationary_left_ipsi   Stationary_left_contra  \
# 0                  321295                 368849                    58834
#
#     Stationary_left_ULquad   Stationary_left_LLquad   Stationary_left_URquad  \
# 0                    92807                   276042                    13581
#
#     Stationary_left_LRquad   Stationary_hands_right   Stationary_right_upper  \
# 0                    45253                   474232                   156070
#
#     Stationary_right_lower   Stationary_right_contra   Stationary_right_ipsi  \
# 0                   318162                     52525                  421707
#
#     Stationary_right_ULquad   Stationary_right_LLquad  \
# 0                     16284                     36241
#
#     Stationary_right_URquad   Stationary_right_LRquad
# ...

# %%
#Proportion of hands during stationary manual object interaction
(dfSt[' Stationary_total'].sum() / dfSt['hands_total'].sum()) * 100
# Out:
# 2.8814990676896928

# %%
#Proportion of hands in the UVF during stationary manual object interaction
((dfSt[' Stationary_left_upper'].sum() + dfSt[' Stationary_right_upper'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 29.100081493267105

# %%
#Proportion of hands in the LVF during stationary manual object interaction
((dfSt[' Stationary_left_lower'].sum() + dfSt[' Stationary_right_lower'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 70.89991850673289

# %%
#Proportion of hands in the ipsilateral field during stationary manual object interaction
((dfSt[' Stationary_left_ipsi'].sum() + dfSt[' Stationary_right_ipsi'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 87.6530493450048

# %%
#Proportion of hands in the contralateral field during stationary manual object interaction
((dfSt[' Stationary_left_contra'].sum() + dfSt[' Stationary_right_contra'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 12.346950654995204

# %%
#Proportion of hands in the upper left quadrant during stationary manual object interaction
((dfSt[' Stationary_left_ULquad'].sum() + dfSt[' Stationary_right_ULquad'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 12.095485716503218

# %%
#Proportion of hands in the lower left quadrant during stationary manual object interaction
((dfSt[' Stationary_left_LLquad'].sum() + dfSt[' Stationary_right_LLquad'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 34.624438001363764

# %%
#Proportion of hands in the upper right quadrant during stationary manual object interaction
((dfSt[' Stationary_left_URquad'].sum() + dfSt[' Stationary_right_URquad'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 17.004595776763885

# %%
#Proportion of hands in the lower right quadrant during stationary manual object interaction
((dfSt[' Stationary_left_LRquad'].sum() + dfSt[' Stationary_right_LRquad'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 36.27548050536913

# %% [markdown]
# ##Stationary objects - Left hand

# %%
#Proportion of left hands in the UVF during stationary manual object interaction
(dfSt[' Stationary_left_upper'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 24.87543344018818

# %%
#Proportion of left hands in the LVF during stationary manual object interaction
(dfSt[' Stationary_left_lower'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 75.12456655981183

# %%
#Proportion of left hands in the ipsilateral field during stationary manual object interaction
(dfSt[' Stationary_left_ipsi'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 86.24354954487319

# %%
#Proportion of left hands in the contralateral field during stationary manual object interaction
(dfSt[' Stationary_left_contra'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 13.756450455126812

# %%
#Proportion of left hands in the upper left quadrant during stationary manual object interaction
(dfSt[' Stationary_left_ULquad'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 21.699950664393956

# %%
#Proportion of left hands in the lower left quadrant during stationary manual object interaction
(dfSt[' Stationary_left_LLquad'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 64.54359888047924

# %%
#Proportion of left hands in the upper right quadrant during stationary manual object interaction
(dfSt[' Stationary_left_URquad'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 3.1754827757942214

# %%
#Proportion of left hands in the lower right quadrant during stationary manual object interaction
(dfSt[' Stationary_left_LRquad'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 10.58096767933259

# %% [markdown]
# ##Stationary objects - Right hand

# %%
#Proportion of right hands in the UVF during stationary manual object interaction
(dfSt[' Stationary_right_upper'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 32.910052463773006

# %%
#Proportion of right hands in the LVF during stationary manual object interaction
(dfSt[' Stationary_right_lower'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 67.08994753622699

# %%
#Proportion of right hands in the ipsilateral field during stationary manual object interaction
(dfSt[' Stationary_right_ipsi'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 88.92419743922805

# %%
#Proportion of right hands in the contralateral field during stationary manual object interaction
(dfSt[' Stationary_right_contra'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 11.075802560771942

# %%
#Proportion of right hands in the upper left quadrant during stationary manual object interaction
(dfSt[' Stationary_right_ULquad'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 3.433762377907859

# %%
#Proportion of right hands in the lower left quadrant during stationary manual object interaction
(dfSt[' Stationary_right_LLquad'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 7.642040182864084

# %%
#Proportion of right hands in the upper right quadrant during stationary manual object interaction
(dfSt[' Stationary_right_URquad'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 29.47629008586515

# %%
#Proportion of right hands in the lower right quadrant during stationary manual object interaction
(dfSt[' Stationary_right_LRquad'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 59.44790735336291

# %% [markdown]
# ##Hand-hand interaction - irrespective of hand side

# %%
#Loading the respective csv file
dfSe = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/obj_interaction_self.csv')
dfSe
# Out:
#    hands_total   hands_Self_total   hands_Self_left   hands_Self_left_upper  \
# 0     31300201             374597            193129                   37679
#
#     hands_Self_left_lower   hands_Self_left_ipsi   hands_Self_left_contra  \
# 0                  155450                 114081                    79048
#
#     hands_Self_left_ULquad   hands_Self_left_LLquad   hands_Self_left_URquad  \
# 0                    24921                    89160                    12758
#
#     hands_Self_left_LRquad   hands_Self_hands_right   hands_Self_right_upper  \
# 0                    66290                   181468                    35435
#
#     hands_Self_right_lower   hands_Self_right_contra   hands_Self_right_ipsi  \
# 0                   146033                     50334                  131134
#
#     hands_Self_right_ULquad   hands_Self_right_LLquad  \
# 0                     10290                     40044
#
#     hands_Self_right_URquad   hands_Self_right_LRquad
# ...

# %%
#Proportion of hands during self-contact 
(dfSe[' hands_Self_total'].sum() / dfSe['hands_total'].sum()) * 100
# Out:
# 1.19678784171386

# %%
#Proportion of hands in the UVF during self-contact 
((dfSe[' hands_Self_left_upper'].sum() + dfSe[' hands_Self_right_upper'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 19.5180420558627

# %%
#Proportion of hands in the LVF during self-contact 
((dfSe[' hands_Self_left_lower'].sum() + dfSe[' hands_Self_right_lower'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 80.48195794413729

# %%
#Proportion of hands in the ipsilateral field during self-contact 
((dfSe[' hands_Self_left_ipsi'].sum() + dfSe[' hands_Self_right_ipsi'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 65.46101543792395

# %%
#Proportion of hands in the contralateral during self-contact 
((dfSe[' hands_Self_left_contra'].sum() + dfSe[' hands_Self_right_contra'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 34.53898456207604

# %%
#Proportion of hands in the upper left quadrant during self-contact 
((dfSe[' hands_Self_left_ULquad'].sum() + dfSe[' hands_Self_right_ULquad'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 9.399701545928025

# %%
#Proportion of hands in the lower left quadrant during self-contact 
((dfSe[' hands_Self_left_LLquad'].sum() + dfSe[' hands_Self_right_LLquad'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 34.4914668296863

# %%
#Proportion of hands in the upper right quadrant during self-contact 
((dfSe[' hands_Self_left_URquad'].sum() + dfSe[' hands_Self_right_URquad'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 10.118340509934677

# %%
#Proportion of hands in the lower right quadrant during self-contact 
((dfSe[' hands_Self_left_LRquad'].sum() + dfSe[' hands_Self_right_LRquad'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 45.990491114451

# %% [markdown]
# ##Hand-hand interaction - Left hand

# %%
#Proportion of left hands in the lower right quadrant during self-contact 
(dfSe[' hands_Self_left_LRquad'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 34.32420817174013

# %%
#Proportion of left hands in the lower left quadrant during self-contact 
(dfSe[' hands_Self_left_LLquad'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 46.16603410155906

# %%
#Proportion of left hands in the upper right quadrant during self-contact 
(dfSe[' hands_Self_left_URquad'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 6.605947320184955

# %%
#Proportion of left hands in the upper left quadrant during self-contact 
(dfSe[' hands_Self_left_ULquad'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 12.903810406515854

# %%
#Proportion of left hands in the contralateral field during self-contact 
(dfSe[' hands_Self_left_contra'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 40.930155491925085

# %%
#Proportion of left hands in the ipsilateral field during self-contact 
(dfSe[' hands_Self_left_ipsi'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 59.06984450807491

# %%
#Proportion of left hands in the LVF during self-contact 
(dfSe[' hands_Self_left_lower'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 80.4902422732992

# %%
#Proportion of left hands in the UVF during self-contact 
(dfSe[' hands_Self_left_upper'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 19.509757726700805

# %% [markdown]
# ##Hand-hand interaction - Right hand

# %%
#Proportion of right hands in the UVF during self-contact 
(dfSe[' hands_Self_right_upper'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 19.526858729913815

# %%
#Proportion of right hands in the LVF during self-contact 
(dfSe[' hands_Self_right_lower'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 80.47314127008619

# %%
#Proportion of right hands in the ipsilateral field during self-contact 
(dfSe[' hands_Self_right_ipsi'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 72.26287830361275

# %%
#Proportion of right hands in the contralateral field during self-contact 
(dfSe[' hands_Self_right_contra'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 27.73712169638724

# %%
#Proportion of right hands in the upper left quadrant during self-contact 
(dfSe[' hands_Self_right_ULquad'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 5.670421231291467

# %%
#Proportion of right hands in the lower left quadrant during self-contact 
(dfSe[' hands_Self_right_LLquad'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 22.066700465095774

# %%
#Proportion of right hands in the upper right quadrant during self-contact 
(dfSe[' hands_Self_right_URquad'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 13.856437498622345

# %%
#Proportion of right hands in the Ulower right quadrant during self-contact 
(dfSe[' hands_Self_right_LRquad'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 58.40644080499041

# %% [markdown]
# \
# #Hand location by handedness

# %% [markdown]
# #Left handers - Irrespective of hand side

# %%
#Loading respective csv file
dfL = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/hands_dataset_analysis_Left.csv')
dfL
# Out:
#    hands_total   hands_left   left_upper   left_lower   left_ipsi  \
# 0      4333315      2217155       499638      1717517     1867318
#
#     left_contra   left_ULquad   left_LLquad   leftURquad   leftLRquad  \
# 0        349837        458797       1408521        40841       308996
#
#     hands_right   right_upper   right_lower   right_contra   right_ipsi  \
# 0       2116160        615043       1501117         193150      1923010
#
#     right_ULquad   right_LLquad   right_URquad   right_LRquad
# 0          68470         124680         546573        1376437

# %%
#Proportion of hands in the LVF, in left handers
((dfL[' left_upper'] + dfL[' right_upper']) / dfL['hands_total']) * 100
# Out:
# 0    25.723517
# dtype: float64

# %%
#Proportion of hands in the UVF, in left handers
((dfL[' left_lower'] + dfL[' right_lower']) / dfL['hands_total']) * 100
# Out:
# 0    74.276483
# dtype: float64

# %%
#Proportion of hands in the ipsilateral field, in left handers
((dfL[' left_ipsi'] + dfL[' right_ipsi']) / dfL['hands_total']) * 100
# Out:
# 0    87.469478
# dtype: float64

# %%
#Proportion of hands in the contralateral field, in left handers
((dfL[' left_contra'] + dfL[' right_contra']) / dfL['hands_total']) * 100
# Out:
# 0    12.530522
# dtype: float64

# %%
#Proportion of hands in the upper left quadrant, in left handers
((dfL[' left_ULquad'] + dfL[' right_ULquad']) / dfL['hands_total']) * 100
# Out:
# 0    12.167751
# dtype: float64

# %%
#Proportion of hands in the lower left quadrant, in left handers
((dfL[' left_LLquad'] + dfL[' right_LLquad']) / dfL['hands_total']) * 100
# Out:
# 0    35.381711
# dtype: float64

# %%
#Proportion of hands in the upper right quadrant, in left handers
((dfL[' leftURquad'] + dfL[' right_URquad']) / dfL['hands_total']) * 100
# Out:
# 0    13.555765
# dtype: float64

# %%
#Proportion of hands in the lower right quadrant, in left handers
((dfL[' leftLRquad'] + dfL[' right_LRquad']) / dfL['hands_total']) * 100
# Out:
# 0    38.894772
# dtype: float64

# %% [markdown]
# ##Left handers - Left hand

# %%
#Proportion of left hands in the UVF, in left handers
(dfL[' left_upper'] / dfL[' hands_left']) * 100
# Out:
# 0    22.535096
# dtype: float64

# %%
#Proportion of left hands in the LVF, in left handers
(dfL[' left_lower'] / dfL[' hands_left']) * 100
# Out:
# 0    77.464904
# dtype: float64

# %%
#Proportion of left hands in the ipsilateral field, in left handers
(dfL[' left_ipsi'] / dfL[' hands_left']) * 100
# Out:
# 0    84.221356
# dtype: float64

# %%
#Proportion of left hands in the contralateral field, in left handers
(dfL[' left_contra'] / dfL[' hands_left']) * 100
# Out:
# 0    15.778644
# dtype: float64

# %%
#Proportion of left hands in the upper left quadrant, in left handers
(dfL[' left_ULquad'] / dfL[' hands_left']) * 100
# Out:
# 0    20.69305
# dtype: float64

# %%
#Proportion of left hands in the lower left quadrant, in left handers
(dfL[' left_LLquad'] / dfL[' hands_left']) * 100
# Out:
# 0    63.528305
# dtype: float64

# %%
#Proportion of left hands in the upper right quadrant, in left handers
(dfL[' leftURquad'] / dfL[' hands_left']) * 100
# Out:
# 0    1.842045
# dtype: float64

# %%
#Proportion of left hands in the lower right quadrant, in left handers
(dfL[' leftLRquad'] / dfL[' hands_left']) * 100
# Out:
# 0    13.936599
# dtype: float64

# %% [markdown]
# ##Left handers - Right hand

# %%
#Proportion of right hands in the UVF, in left handers
(dfL[' right_upper'] / dfL[' hands_right']) * 100
# Out:
# 0    29.064107
# dtype: float64

# %%
#Proportion of right hands in the LVF, in left handers
(dfL[' right_lower'] / dfL[' hands_right']) * 100
# Out:
# 0    70.935893
# dtype: float64

# %%
#Proportion of right hands in the ipsilateral field, in left handers
(dfL[' right_ipsi'] / dfL[' hands_right']) * 100
# Out:
# 0    90.872618
# dtype: float64

# %%
#Proportion of right hands in the contralateral field, in left handers
(dfL[' right_contra'] / dfL[' hands_right']) * 100
# Out:
# 0    9.127382
# dtype: float64

# %%
#Proportion of right hands in the upper left quadrant, in left handers
(dfL[' right_ULquad'] / dfL[' hands_right']) * 100
# Out:
# 0    3.235578
# dtype: float64

# %%
#Proportion of right hands in the lower left quadrant, in left handers
(dfL[' right_LLquad'] / dfL[' hands_right']) * 100
# Out:
# 0    5.891804
# dtype: float64

# %%
#Proportion of right hands in the upper right quadrant, in left handers
(dfL[' right_URquad'] / dfL[' hands_right']) * 100
# Out:
# 0    25.828529
# dtype: float64

# %%
#Proportion of right hands in the lower right quadrant, in left handers
(dfL[' right_LRquad'] / dfL[' hands_right']) * 100
# Out:
# 0    65.044089
# dtype: float64

# %%
print('Total number of left hand frames = ' + str(dfL[' hands_left'].sum()))
# Out:
# Total number of left hand frames = 2217155

# %%
print('Total number of right hand frames = ' + str(dfL[' hands_right'].sum()))
# Out:
# Total number of right hand frames = 2116160

# %% [markdown]
# \
# #Left handers - Hand-Object Interaction (proportions)
# ##No object interaction

# %%
#Loading respective csv file
dfNo = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/leftHand_hands_noContact_analysis.csv')
dfNo
# Out:
#    hands_total   noContact_total   noContact_left   noContact_left_upper  \
# 0      4333315            582366           262129                  32216
#
#     noContact_left_lower   noContact_left_ipsi   noContact_left_contra  \
# 0                 229913                208686                   53443
#
#     noContact_left_ULquad   noContact_left_LLquad   noContact_left_URquad  \
# 0                   28112                  180574                    4104
#
#     noContact_left_LRquad   noContact_hands_right   noContact_right_upper  \
# 0                   49339                  320237                   58713
#
#     noContact_right_lower   noContact_right_contra   noContact_right_ipsi  \
# 0                  261524                    34570                 285667
#
#     noContact_right_ULquad   noContact_right_LLquad   noContact_right_URquad  \
# 0                     7424                    27146                    51289
#
#     noContact_right_LRquad
# 0                   234378

# %% [markdown]
# ##Left handers - No object interaction - Irrespective of hand side

# %%
#Proportion of hands during no contact, in left handers
(dfNo[' noContact_total'].sum() / dfNo['hands_total'].sum()) * 100
# Out:
# 13.439272243074873

# %%
#Proportion of hands during no contact in the UVF, in left handers
((dfNo[' noContact_left_upper'].sum() + dfNo[' noContact_right_upper'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 15.613720581215249

# %%
#Proportion of hands during no contact in the LVF, in left handers
((dfNo[' noContact_left_lower'].sum() + dfNo[' noContact_right_lower'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 84.38627941878475

# %%
#Proportion of hands during no contact in the ipsilateral field, in left handers
((dfNo[' noContact_left_ipsi'].sum() + dfNo[' noContact_right_ipsi'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 84.88699546333406

# %%
#Proportion of hands during no contact in the contralateral field, in left handers
((dfNo[' noContact_left_contra'].sum() + dfNo[' noContact_right_contra'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 15.113004536665944

# %%
#Proportion of hands during no contact in the upper left quadrant, in left handers
((dfNo[' noContact_left_ULquad'].sum() + dfNo[' noContact_right_ULquad'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 6.102004581311409

# %%
#Proportion of hands during no contact in the lower left quadrant, in left handers
((dfNo[' noContact_left_LLquad'].sum() + dfNo[' noContact_right_LLquad'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 35.668291074684994

# %%
#Proportion of hands during no contact in the upper right quadrant, in left handers
((dfNo[' noContact_left_URquad'].sum() + dfNo[' noContact_right_URquad'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 9.51171599990384

# %%
#Proportion of hands during no contact in the lower right quadrant, in left handers
((dfNo[' noContact_left_LRquad'].sum() + dfNo[' noContact_right_LRquad'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 48.71798834409976

# %% [markdown]
# ##Left handers - No object interaction - Left hand

# %%
#Proportion of left hands during no contact in the UVF, in left handers
(dfNo[' noContact_left_upper'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 12.29013195792911

# %%
#Proportion of left hands during no contact in the LVF, in left handers
(dfNo[' noContact_left_lower'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 87.7098680420709

# %%
#Proportion of left hands during no contact in the ipsilateral field, in left handers
(dfNo[' noContact_left_ipsi'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 79.6119467895578

# %%
#Proportion of left hands during no contact in the contralateral field, in left handers
(dfNo[' noContact_left_contra'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 20.388053210442187

# %%
#Proportion of hands during no contact in the upper left quadrant, in left handers
(dfNo[' noContact_left_ULquad'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 10.724490613400272

# %%
#Proportion of left hands during no contact in the lower left quadrant, in left handers
(dfNo[' noContact_left_LLquad'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 68.88745617615754

# %%
#Proportion of left hands during no contact in the upper right quadrant, in left handers
(dfNo[' noContact_left_URquad'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 1.5656413445288386

# %%
#Proportion of left hands during no contact in the lower right quadrant, in left handers
(dfNo[' noContact_left_LRquad'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 18.82241186591335

# %% [markdown]
# ##Left handers - No object interaction - Right hand

# %%
#Proportion of right hands during no contact in the UVF, in left handers
(dfNo[' noContact_right_upper'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 18.334233708159893

# %%
#Proportion of right hands during no contact in the LVF, in left handers
(dfNo[' noContact_right_lower'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 81.6657662918401

# %%
#Proportion of right hands during no contact in the ipsilateral field, in left handers
(dfNo[' noContact_right_ipsi'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 89.20487014305031

# %%
#Proportion of right hands during no contact in the contralateral field, in left handers
(dfNo[' noContact_right_contra'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 10.795129856949696

# %%
#Proportion of right hands during no contact in the upper left quadrant, in left handers
(dfNo[' noContact_right_ULquad'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 2.3182830216370998

# %%
#Proportion of right hands during no contact in the lower left quadrant, in left handers
(dfNo[' noContact_right_LLquad'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 8.476846835312598

# %%
#Proportion of right hands during no contact in the upper right quadrant, in left handers
(dfNo[' noContact_right_URquad'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 16.015950686522796

# %%
#Proportion of right hands during no contact in the lower right quadrant, in left handers
(dfNo[' noContact_right_LRquad'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 73.18891945652751

# %% [markdown]
# ##Left handers - Portable objects - Irrespective of hand side

# %%
#Loading the respective csv file
dfPo = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/leftHanders_Portable.csv')
dfPo
# Out:
#    hands_total   portable_total   portable_left   portable_left_upper  \
# 0      4333315          3534648         1862797                447608
#
#     portable_left_lower   portable_left_ipsi   portable_left_contra  \
# 0               1415189              1587239                 275558
#
#     portable_left_ULquad   portable_left_LLquad   portable_left_URquad  \
# 0                 414311                1172928                  33297
#
#     portable_left_LRquad   portable_hands_right   portablet_right_upper  \
# 0                 242261                1671851                  529277
#
#     portable_right_lower   portable_right_contra   portable_right_ipsi  \
# 0                1142574                  143924               1527927
#
#     portable_right_ULquad   portable_right_LLquad   portable_right_URquad  \
# 0                   56713                   87211                  472564
#
#     portable_right_LRquad
# 0                 1055363

# %%
#Proportion of hands during dynamic object interaction in left handers
(dfPo[' portable_total'].sum() / dfPo['hands_total'].sum()) * 100
# Out:
# 81.56914510022926

# %%
#Proportion of hands during dynamic object interaction in the UVF, in left handers
((dfPo[' portable_left_upper'].sum() + dfPo[' portablet_right_upper'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 27.637405478565334

# %%
#Proportion of hands during dynamic object interaction in the LVF, in left handers
((dfPo[' portable_left_lower'].sum() + dfPo[' portable_right_lower'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 72.36259452143466

# %%
#Proportion of hands during dynamic object interaction in the ipsilateral field, in left handers
((dfPo[' portable_left_ipsi'].sum() + dfPo[' portable_right_ipsi'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 88.13228361070183

# %%
#Proportion of hands during dynamic object interaction in the contralateral field, in left handers
((dfPo[' portable_left_contra'].sum() + dfPo[' portable_right_contra'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 11.86771638929817

# %%
#Proportion of hands during dynamic object interaction in the upper left quadrant, in left handers
((dfPo[' portable_left_ULquad'].sum() + dfPo[' portable_right_ULquad'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 13.325909680398162

# %%
#Proportion of hands during dynamic object interaction in the lower left quadrant, in left handers
((dfPo[' portable_left_LLquad'].sum() + dfPo[' portable_right_LLquad'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 35.65104644083371

# %%
#Proportion of hands during dynamic object interaction in the upper right quadrant, in left handers
((dfPo[' portable_left_URquad'].sum() + dfPo[' portable_right_URquad'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 14.311495798167172

# %%
#Proportion of hands during dynamic object interaction in the lower right quadrant, in left handers
((dfPo[' portable_left_LRquad'].sum() + dfPo[' portable_right_LRquad'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 36.711548080600956

# %% [markdown]
# ##Left handers - Portable objects - Left Hand

# %%
#Proportion of left hands during dynamic object interaction in the UVF, in left handers
(dfPo[' portable_left_upper'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 24.028812586664035

# %%
#Proportion of left hands during dynamic object interaction in the LVF, in left handers
(dfPo[' portable_left_lower'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 75.97118741333597

# %%
#Proportion of left hands during dynamic object interaction in the ipsilateral field, in left handers
(dfPo[' portable_left_ipsi'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 85.20729848716742

# %%
#Proportion of left hands during dynamic object interaction in the contralateral field, in left handers
(dfPo[' portable_left_contra'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 14.792701512832584

# %%
#Proportion of left hands during dynamic object interaction in the upper left quadrant, in left handers
(dfPo[' portable_left_ULquad'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 22.24133923342157

# %%
#Proportion of left hands during dynamic object interaction in the lower left quadrant, in left handers
(dfPo[' portable_left_LLquad'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 62.96595925374584

# %%
#Proportion of left hands during dynamic object interaction in the upper right quadrant, in left handers
(dfPo[' portable_left_URquad'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 1.787473353242463

# %%
#Proportion of left hands during dynamic object interaction in the lower right quadrant, in left handers
(dfPo[' portable_left_LRquad'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 13.005228159590121

# %% [markdown]
# ##Left handers - Portable objects - Right hand

# %%
#Proportion of right hands during dynamic object interaction in the UVF, in left handers
(dfPo[' portablet_right_upper'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 31.658144176723884

# %%
#Proportion of right hands during dynamic object interaction in the LVF, in left handers
(dfPo[' portable_right_lower'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 68.34185582327612

# %%
#Proportion of right hands during dynamic object interaction in the ipsilateral field, in left handers
(dfPo[' portable_right_ipsi'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 91.39133810369465

# %%
#Proportion of right hands during dynamic object interaction in the contralateral field, in left handers
(dfPo[' portable_right_contra'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 8.608661896305353

# %%
#Proportion of right hands during dynamic object interaction in the upper left quadrant, in left handers
(dfPo[' portable_right_ULquad'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 3.392228135162763

# %%
#Proportion of right hands during dynamic object interaction in the lower left quadrant, in left handers
(dfPo[' portable_right_LLquad'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 5.21643376114259

# %%
#Proportion of right hands during dynamic object interaction in the upper right quadrant, in left handers
(dfPo[' portable_right_URquad'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 28.265916041561116

# %%
#Proportion of right hands during dynamic object interaction in the lower right quadrant, in left handers
(dfPo[' portable_right_LRquad'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 63.12542206213353

# %% [markdown]
# ##Left handers - Stationary objects - Irespective of hand side

# %%
#Loading the respective csv file
dfSt = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/leftHander_Stationary.csv')
dfSt
# Out:
#    hands_total   Stationary_total   Stationary_left   Stationary_left_upper  \
# 0      4333315             167242             66899                   15095
#
#     Stationary_left_lower   Stationary_left_ipsi   Stationary_left_contra  \
# 0                   51804                  56078                    10821
#
#     Stationary_left_ULquad   Stationary_left_LLquad   Stationary_left_URquad  \
# 0                    12716                    43362                     2379
#
#     Stationary_left_LRquad   Stationary_hands_right   Stationary_right_upper  \
# 0                     8442                   100343                    22397
#
#     Stationary_right_lower   Stationary_right_contra   Stationary_right_ipsi  \
# 0                    77946                      7781                   92562
#
#     Stationary_right_ULquad   Stationary_right_LLquad  \
# 0                      2630                      5151
#
#     Stationary_right_URquad   Stationary_right_LRquad
# ...

# %%
#Proportion of hands during stationary object interaction, in left handers
(dfSt[' Stationary_total'].sum() / dfSt['hands_total'].sum()) * 100
# Out:
# 3.859447097660798

# %%
#Proportion of hands during stationary object interaction in the UVF, in left handers
((dfSt[' Stationary_left_upper'].sum() + dfSt[' Stationary_right_upper'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 22.41781370708315

# %%
#Proportion of hands during stationary object interaction in the LVF, in left handers
((dfSt[' Stationary_left_lower'].sum() + dfSt[' Stationary_right_lower'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 77.58218629291686

# %%
#Proportion of hands during stationary object interaction in the ipsilateral field, in left handers
((dfSt[' Stationary_left_ipsi'].sum() + dfSt[' Stationary_right_ipsi'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 88.87719591968525

# %%
#Proportion of hands during stationary object interaction in the contralateral field, in left handers
((dfSt[' Stationary_left_contra'].sum() + dfSt[' Stationary_right_contra'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 11.122804080314754

# %%
#Proportion of hands during stationary object interaction in the upper left quadrant, in left handers
((dfSt[' Stationary_left_ULquad'].sum() + dfSt[' Stationary_right_ULquad'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 9.175924707908301

# %%
#Proportion of hands during stationary object interaction in the lower left quadrant, in left handers
((dfSt[' Stationary_left_LLquad'].sum() + dfSt[' Stationary_right_LLquad'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 29.00766553856089

# %%
#Proportion of hands during stationary object interaction in the upper right quadrant, in left handers
((dfSt[' Stationary_left_URquad'].sum() + dfSt[' Stationary_right_URquad'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 13.241888999174847

# %%
#Proportion of hands during stationary object interaction in the lower right quadrant, in left handers
((dfSt[' Stationary_left_LRquad'].sum() + dfSt[' Stationary_right_LRquad'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 48.574520754355966

# %% [markdown]
# ##Left handers - Stationary objects - Left hand

# %%
#Proportion of left hands during stationary object interaction in the UVF, in left handers
(dfSt[' Stationary_left_upper'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 22.563864930716456

# %%
#Proportion of left hands during stationary object interaction in the LVF, in left handers
(dfSt[' Stationary_left_lower'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 77.43613506928355

# %%
#Proportion of left hands during stationary object interaction in the ipsilateral field, in left handers
(dfSt[' Stationary_left_ipsi'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 83.82487032691071

# %%
#Proportion of left hands during stationary object interaction in the contralateral field, in left handers
(dfSt[' Stationary_left_contra'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 16.175129673089284

# %%
#Proportion of left hands during stationary object interaction in the upper left quadrant, in left handers
(dfSt[' Stationary_left_ULquad'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 19.007757963497212

# %%
#Proportion of left hands during stationary object interaction in the lower left quadrant, in left handers
(dfSt[' Stationary_left_LLquad'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 64.81711236341351

# %%
#Proportion of left hands during stationary object interaction in the upper right quadrant, in left handers
(dfSt[' Stationary_left_URquad'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 3.5561069672192405

# %%
#Proportion of left hands during stationary object interaction in the lower right quadrant, in left handers
(dfSt[' Stationary_left_LRquad'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 12.619022705870043

# %% [markdown]
# ##Left handers - Stationary objects - Right hand

# %%
#Proportion of right hands during stationary object interaction in the UVF, in left handers
(dfSt[' Stationary_right_upper'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 22.320440887754998

# %%
#Proportion of right hands during stationary object interaction in the LVF, in left handers
(dfSt[' Stationary_right_lower'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 77.679559112245

# %%
#Proportion of right hands during stationary object interaction in the ipsilateral field, in left handers
(dfSt[' Stationary_right_ipsi'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 92.2455976002312

# %%
#Proportion of right hands during stationary object interaction in the contralateral field, in left handers
(dfSt[' Stationary_right_contra'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 7.754402399768794

# %%
#Proportion of right hands during stationary object interaction in the upper left quadrant, in left handers
(dfSt[' Stationary_right_ULquad'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 2.621009935919795

# %%
#Proportion of right hands during stationary object interaction in the lower left quadrant, in left handers
(dfSt[' Stationary_right_LLquad'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 5.133392463848998

# %%
#Proportion of right hands during stationary object interaction in the upper right quadrant, in left handers
(dfSt[' Stationary_right_URquad'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 19.699430951835208

# %%
#Proportion of right hands during stationary object interaction in the lower right quadrant, in left handers
(dfSt[' Stationary_right_LRquad'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 72.54616664839601

# %% [markdown]
# ##Left handers - Hand-hand interaction - irrespective of hand side

# %%
#Loading the respective csv file
dfSe = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/leftHanders_self.csv')
dfSe
# Out:
#    hands_total   hands_Self_total   hands_Self_left   hands_Self_left_upper  \
# 0      4333315              49059             25330                    4719
#
#     hands_Self_left_lower   hands_Self_left_ipsi   hands_Self_left_contra  \
# 0                   20611                  15315                    10015
#
#     hands_Self_left_ULquad   hands_Self_left_LLquad   hands_Self_left_URquad  \
# 0                     3658                    11657                     1061
#
#     hands_Self_left_LRquad   hands_Self_hands_right   hands_Self_right_upper  \
# 0                     8954                    23729                     4656
#
#     hands_Self_right_lower   hands_Self_right_contra   hands_Self_right_ipsi  \
# 0                    19073                      6875                   16854
#
#     hands_Self_right_ULquad   hands_Self_right_LLquad  \
# 0                      1703                      5172
#
#     hands_Self_right_URquad   hands_Self_right_LRquad
# ...

# %%
#Proportion of hands during self-contact, in left handers
(dfSe[' hands_Self_total'].sum() / dfSe['hands_total'].sum()) * 100
# Out:
# 1.1321355590350575

# %%
#Proportion of hands during self-contact in the UVF, in left handers
((dfSe[' hands_Self_left_upper'].sum() + dfSe[' hands_Self_right_upper'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 19.10964349049104

# %%
#Proportion of hands during self-contact in the LVF, in left handers
((dfSe[' hands_Self_left_lower'].sum() + dfSe[' hands_Self_right_lower'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 80.89035650950895

# %%
#Proportion of hands during self-contact in the ipsilateral field, in left handers
((dfSe[' hands_Self_left_ipsi'].sum() + dfSe[' hands_Self_right_ipsi'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 65.57206628753134

# %%
#Proportion of hands during self-contact in the contralateral field, in left handers
((dfSe[' hands_Self_left_contra'].sum() + dfSe[' hands_Self_right_contra'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 34.42793371246866

# %%
#Proportion of hands during self-contact in the upper left quadrant, in left handers
((dfSe[' hands_Self_left_ULquad'].sum() + dfSe[' hands_Self_right_ULquad'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 10.927658533602397

# %%
#Proportion of hands during self-contact in the lower left quadrant, in left handers
((dfSe[' hands_Self_left_LLquad'].sum() + dfSe[' hands_Self_right_LLquad'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 34.303593632157195

# %%
#Proportion of hands during self-contact in the upper right quadrant, in left handers
((dfSe[' hands_Self_left_URquad'].sum() + dfSe[' hands_Self_right_URquad'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 8.181984956888645

# %%
#Proportion of hands during self-contact in the lower right quadrant, in left handers
((dfSe[' hands_Self_left_LRquad'].sum() + dfSe[' hands_Self_right_LRquad'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 46.58676287735176

# %% [markdown]
# ##Left handers - Hand-hand interaction - Left hand

# %%
#Proportion of left hands during self-contact in the lower right quadrant, in left handers
(dfSe[' hands_Self_left_LRquad'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 35.3493880773786

# %%
#Proportion of left hands during self-contact in the lower left quadrant, in left handers
(dfSe[' hands_Self_left_LLquad'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 46.02052901697592

# %%
#Proportion of left hands during self-contact in the upper right quadrant, in left handers
(dfSe[' hands_Self_left_URquad'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 4.1887090406632455

# %%
#Proportion of left hands during self-contact in the upper left quadrant, in left handers
(dfSe[' hands_Self_left_ULquad'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 14.441373864982236

# %%
#Proportion of left hands during self-contact in the contralateral field, in left handers
(dfSe[' hands_Self_left_contra'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 39.53809711804185

# %%
#Proportion of left hands during self-contact in the ipsilateral field, in left handers
(dfSe[' hands_Self_left_ipsi'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 60.46190288195815

# %%
#Proportion of left hands during self-contact in the LVF, in left handers
(dfSe[' hands_Self_left_lower'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 81.36991709435452

# %%
#Proportion of left hands during self-contact in the UVF, in left handers
(dfSe[' hands_Self_left_upper'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 18.63008290564548

# %% [markdown]
# ##Left handers - Hand-hand interaction - Right hand

# %%
#Proportion of right hands during self-contact in the UVF, in left handers
(dfSe[' hands_Self_right_upper'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 19.621560116313372

# %%
#Proportion of right hands during self-contact in the LVF, in left handers
(dfSe[' hands_Self_right_lower'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 80.37843988368662

# %%
#Proportion of right hands during self-contact in the ipsilateral field, in left handers
(dfSe[' hands_Self_right_ipsi'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 71.02701335918074

# %%
#Proportion of right hands during self-contact in the contralateral field, in left handers
(dfSe[' hands_Self_right_contra'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 28.972986640819247

# %%
#Proportion of right hands during self-contact in the upper left quadrant, in left handers
(dfSe[' hands_Self_right_ULquad'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 7.176872181718571

# %%
#Proportion of right hands during self-contact in the lower left quadrant, in left handers
(dfSe[' hands_Self_right_LLquad'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 21.79611445910068

# %%
#Proportion of right hands during self-contact in the upper right quadrant, in left handers
(dfSe[' hands_Self_right_URquad'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 12.4446879345948

# %%
#Proportion of right hands during self-contact in the lower right quadrant, in left handers
(dfSe[' hands_Self_right_LRquad'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 58.582325424585946

# %% [markdown]
# #Right dominant hand participants

# %%
#Loading the respective csv file
dfR = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/hands_dataset_analysis_Right.csv')
dfR
# Out:
#    hands_total   hands_left   left_upper   left_lower   left_ipsi  \
# 0     26966886     12959122      2750823     10208299    10918940
#
#     left_contra   left_ULquad   left_LLquad   leftURquad   leftLRquad  \
# 0       2040182       2322655       8596285       428168      1612014
#
#     hands_right   right_upper   right_lower   right_contra   right_ipsi  \
# 0      14007764       3662830      10344934        1294454     12713310
#
#     right_ULquad   right_LLquad   right_URquad   right_LRquad
# 0         270375        1024079        3392455        9320855

# %%
#Proportion of hands in the UVF, in right handers
((dfR[' left_upper'] + dfR[' right_upper']) / dfR['hands_total']) * 100
# Out:
# 0    23.783439
# dtype: float64

# %%
#Proportion of hands in the LVF, in right handers
((dfR[' left_lower'] + dfR[' right_lower']) / dfR['hands_total']) * 100
# Out:
# 0    76.216561
# dtype: float64

# %%
#Proportion of hands in the ipsilateral field, in right handers
((dfR[' left_ipsi'] + dfR[' right_ipsi']) / dfR['hands_total']) * 100
# Out:
# 0    87.63433
# dtype: float64

# %%
#Proportion of hands in the contralateral field, in right handers
((dfR[' left_contra'] + dfR[' right_contra']) / dfR['hands_total']) * 100
# Out:
# 0    12.36567
# dtype: float64

# %%
#Proportion of hands in the upper left quadrant, in right handers
((dfR[' left_ULquad'] + dfR[' right_ULquad']) / dfR['hands_total']) * 100
# Out:
# 0    9.615608
# dtype: float64

# %%
#Proportion of hands in the lower left quadrant, in right handers
((dfR[' left_LLquad'] + dfR[' right_LLquad']) / dfR['hands_total']) * 100
# Out:
# 0    35.674731
# dtype: float64

# %%
#Proportion of hands in the upper right quadrant, in right handers
((dfR[' leftURquad'] + dfR[' right_URquad']) / dfR['hands_total']) * 100
# Out:
# 0    14.167832
# dtype: float64

# %%
#Proportion of hands in the lower right quadrant, in right handers
((dfR[' leftLRquad'] + dfR[' right_LRquad']) / dfR['hands_total']) * 100
# Out:
# 0    40.54183
# dtype: float64

# %% [markdown]
# ##Left hand

# %%
#Proportion of left hands in the UVF, in right handers
(dfR[' left_upper'] / dfR[' hands_left']) * 100
# Out:
# 0    21.226924
# dtype: float64

# %%
#Proportion of left hands in the LVF, in right handers
(dfR[' left_lower'] / dfR[' hands_left']) * 100
# Out:
# 0    78.773076
# dtype: float64

# %%
#Proportion of left hands in the ipsilateral field, in right handers
(dfR[' left_ipsi'] / dfR[' hands_left']) * 100
# Out:
# 0    84.256788
# dtype: float64

# %%
#Proportion of left hands in the contrlateral field, in right handers
(dfR[' left_contra'] / dfR[' hands_left']) * 100
# Out:
# 0    15.743212
# dtype: float64

# %%
#Proportion of left hands in the upper left quadrant, in right handers
(dfR[' left_ULquad'] / dfR[' hands_left']) * 100
# Out:
# 0    17.922935
# dtype: float64

# %%
#Proportion of left hands in the lower left quadrant, in right handers
(dfR[' left_LLquad'] / dfR[' hands_left']) * 100
# Out:
# 0    66.333853
# dtype: float64

# %%
#Proportion of left hands in the upper right quadrant, in right handers
(dfR[' leftURquad'] / dfR[' hands_left']) * 100
# Out:
# 0    3.303989
# dtype: float64

# %%
#Proportion of left hands in the lower right, in right handers
(dfR[' leftLRquad'] / dfR[' hands_left']) * 100
# Out:
# 0    12.439222
# dtype: float64

# %% [markdown]
# ##Right hand

# %%
#Proportion of right hands in the UVF, in right handers
(dfR[' right_upper'] / dfR[' hands_right']) * 100
# Out:
# 0    26.14857
# dtype: float64

# %%
#Proportion of right hands in the LVF, in right handers
(dfR[' right_lower'] / dfR[' hands_right']) * 100
# Out:
# 0    73.85143
# dtype: float64

# %%
#Proportion of right hands in the ipsilateral field, in right handers
(dfR[' right_ipsi'] / dfR[' hands_right']) * 100
# Out:
# 0    90.759025
# dtype: float64

# %%
#Proportion of right hands in the contralateral field, in right handers
(dfR[' right_contra'] / dfR[' hands_right']) * 100
# Out:
# 0    9.240975
# dtype: float64

# %%
#Proportion of right hands in the upper left quadrant, in right handers
(dfR[' right_ULquad'] / dfR[' hands_right']) * 100
# Out:
# 0    1.93018
# dtype: float64

# %%
#Proportion of right hands in the lower left quadrant, in right handers
(dfR[' right_LLquad'] / dfR[' hands_right']) * 100
# Out:
# 0    7.310796
# dtype: float64

# %%
#Proportion of right hands in the upper right quadrant, in right handers
(dfR[' right_URquad'] / dfR[' hands_right']) * 100
# Out:
# 0    24.218391
# dtype: float64

# %%
#Proportion of right hands in the lower right quadrant, in right handers
(dfR[' right_LRquad'] / dfR[' hands_right']) * 100
# Out:
# 0    66.540634
# dtype: float64

# %% [markdown]
# \
# #Right handers - Hand-Object Interaction (proportions)
# ##No object interaction

# %%
#Loading the respective csv file
dfNo = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/rightHand_hands_noContact_analysis.csv')
dfNo
# Out:
#    hands_total   noContact_total   noContact_left   noContact_left_upper  \
# 0     26966886           3386497          1829837                 255624
#
#     noContact_left_lower   noContact_left_ipsi   noContact_left_contra  \
# 0                1574213               1543051                  286786
#
#     noContact_left_ULquad   noContact_left_LLquad   noContact_left_URquad  \
# 0                  213416                 1329635                   42208
#
#     noContact_left_LRquad   noContact_hands_right   noContact_right_upper  \
# 0                  244578                 1556660                  329440
#
#     noContact_right_lower   noContact_right_contra   noContact_right_ipsi  \
# 0                 1227220                   206935                1349725
#
#     noContact_right_ULquad   noContact_right_LLquad   noContact_right_URquad  \
# 0                    37387                   169548                   292053
#
#     noContact_right_LRquad
# 0                  1057672

# %% [markdown]
# ##Right handers - No object interaction - Irrespective of hand side

# %%
#Proportion of hands during no object interaction, in right handers
(dfNo[' noContact_total'].sum() / dfNo['hands_total'].sum()) * 100
# Out:
# 12.55798315014941

# %%
#Proportion of hands in the UVF during no object interaction, in right handers
((dfNo[' noContact_left_upper'].sum() + dfNo[' noContact_right_upper'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 17.276377330320976

# %%
#Proportion of hands in the LVF during no object interaction, in right handers
((dfNo[' noContact_left_lower'].sum() + dfNo[' noContact_right_lower'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 82.72362266967902

# %%
#Proportion of hands in the ipsilateral field during no object interaction, in right handers
((dfNo[' noContact_left_ipsi'].sum() + dfNo[' noContact_right_ipsi'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 85.42089362547789

# %%
#Proportion of hands in the contralateral field during no object interaction, in right handers
((dfNo[' noContact_left_contra'].sum() + dfNo[' noContact_right_contra'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 14.57910637452211

# %%
#Proportion of hands in the upper left quadrant during no object interaction, in right handers
((dfNo[' noContact_left_ULquad'].sum() + dfNo[' noContact_right_ULquad'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 7.405971421206043

# %%
#Proportion of hands in the lower left quadrant during no object interaction, in right handers
((dfNo[' noContact_left_LLquad'].sum() + dfNo[' noContact_right_LLquad'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 44.26943239577652

# %%
#Proportion of hands in the upper right during no object interaction, in right handers
((dfNo[' noContact_left_URquad'].sum() + dfNo[' noContact_right_URquad'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 9.870405909114934

# %%
#Proportion of hands in the lower right during no object interaction, in right handers
((dfNo[' noContact_left_LRquad'].sum() + dfNo[' noContact_right_LRquad'].sum()) / dfNo[' noContact_total'].sum()) * 100
# Out:
# 38.4541902739025

# %% [markdown]
# ##Right handers - No object interaction - Left hand

# %%
#Proportion of left hands in the UVF during no object interaction, in right handers
(dfNo[' noContact_left_upper'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 13.969768891983275

# %%
#Proportion of left hands in the LVF during no object interaction, in right handers
(dfNo[' noContact_left_lower'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 86.03023110801674

# %%
#Proportion of left hands in the ipsilateral field during no object interaction, in right handers
(dfNo[' noContact_left_ipsi'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 84.32723789058807

# %%
#Proportion of left hands in the contralateral field during no object interaction, in right handers
(dfNo[' noContact_left_contra'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 15.67276210941193

# %%
#Proportion of left hands in the upper left quadrant during no object interaction, in right handers
(dfNo[' noContact_left_ULquad'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 11.66311534852558

# %%
#Proportion of left hands in the lower left quadrant during no object interaction, in right handers
(dfNo[' noContact_left_LLquad'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 72.66412254206249

# %%
#Proportion of left hands in the upper right quadrant during no object interaction, in right handers
(dfNo[' noContact_left_URquad'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 2.306653543457696

# %%
#Proportion of left hands in the lower right quadrant during no object interaction, in right handers
(dfNo[' noContact_left_LRquad'].sum() / dfNo[' noContact_left'].sum()) * 100
# Out:
# 13.366108565954235

# %% [markdown]
# ##Right handers - No object interaction - Right hand

# %%
#Proportion of right hands in the UVF during no object interaction, in right handers
(dfNo[' noContact_right_upper'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 21.163259799827834

# %%
#Proportion of right hands in the LVF during no object interaction, in right handers
(dfNo[' noContact_right_lower'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 78.83674020017216

# %%
#Proportion of right hands in the ipsilateral field during no object interaction, in right handers
(dfNo[' noContact_right_ipsi'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 86.70647411766217

# %%
#Proportion of right hands in the contralateral field during no object interaction, in right handers
(dfNo[' noContact_right_contra'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 13.293525882337825

# %%
#Proportion of right hands in the upper left quadrant during no object interaction, in right handers
(dfNo[' noContact_right_ULquad'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 2.401744761219534

# %%
#Proportion of right hands in the lower left quadrant during no object interaction, in right handers
(dfNo[' noContact_right_LLquad'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 10.891781121118292

# %%
#Proportion of right hands in the upper right quadrant during no object interaction, in right handers
(dfNo[' noContact_right_URquad'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 18.761515038608305

# %%
#Proportion of right hands in the lower right quadrant during no object interaction, in right handers
(dfNo[' noContact_right_LRquad'].sum() / dfNo[' noContact_hands_right'].sum()) * 100
# Out:
# 67.94495907905387

# %% [markdown]
# ##Right handers - Portable objects - Irrespective of hand side

# %%
#Loading the respective csv file
dfPo = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/rightHanders_Portable.csv')
dfPo
# Out:
#    hands_total   portable_total   portable_left   portable_left_upper  \
# 0     26966886         22520178        10600702               2370946
#
#     portable_left_lower   portable_left_ipsi   portable_left_contra  \
# 0               8229756              8964352                1636350
#
#     portable_left_ULquad   portable_left_LLquad   portable_left_URquad  \
# 0                2007885                6956467                 363061
#
#     portable_left_LRquad   portable_hands_right   portablet_right_upper  \
# 0                1273289               11919476                 3168938
#
#     portable_right_lower   portable_right_contra   portable_right_ipsi  \
# 0                8750538                  999316              10920160
#
#     portable_right_ULquad   portable_right_LLquad   portable_right_URquad  \
# 0                  210747                  788569                 2958191
#
#     portable_right_LRquad
# 0                 7961969

# %%
#Proportion of hands during dynamic object interaction, in right handers
(dfPo[' portable_total'].sum() / dfPo['hands_total'].sum()) * 100
# Out:
# 83.51048764028594

# %%
#Proportion of hands in the UVF during dynamic object interaction, in right handers
((dfPo[' portable_left_upper'].sum() + dfPo[' portablet_right_upper'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 24.599645704398963

# %%
#Proportion of hands in the LVF during dynamic object interaction, in right handers
((dfPo[' portable_left_lower'].sum() + dfPo[' portable_right_lower'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 75.40035429560103

# %%
#Proportion of hands in the ipsilateral field during dynamic object interaction, in right handers
((dfPo[' portable_left_ipsi'].sum() + dfPo[' portable_right_ipsi'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 88.29642465525805

# %%
#Proportion of hands in the contralateral field during dynamic object interaction, in right handers
((dfPo[' portable_left_contra'].sum() + dfPo[' portable_right_contra'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 11.703575344741948

# %%
#Proportion of hands in the upper left quadrant during dynamic object interaction, in right handers
((dfPo[' portable_left_ULquad'].sum() + dfPo[' portable_right_ULquad'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 9.851751615817602

# %%
#Proportion of hands in the lower left quadrant during dynamic object interaction, in right handers
((dfPo[' portable_left_LLquad'].sum() + dfPo[' portable_right_LLquad'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 34.39153988924954

# %%
#Proportion of hands in the upper right quadrant during dynamic object interaction, in right handers
((dfPo[' portable_left_URquad'].sum() + dfPo[' portable_right_URquad'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 14.74789408858136

# %%
#Proportion of hands in the lower right quadrant during dynamic object interaction, in right handers
((dfPo[' portable_left_LRquad'].sum() + dfPo[' portable_right_LRquad'].sum()) / dfPo[' portable_total'].sum()) * 100
# Out:
# 41.0088144063515

# %% [markdown]
# ##Right handers - Portable objects - Left Hand

# %%
#Proportion of left hands in the UVF during dynamic object interaction, in right handers
(dfPo[' portable_left_upper'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 22.365933878718597

# %%
#Proportion of left hands in the LVF during dynamic object interaction, in right handers
(dfPo[' portable_left_lower'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 77.63406612128139

# %%
#Proportion of left hands in the ipsilateral field during dynamic object interaction, in right handers
(dfPo[' portable_left_ipsi'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 84.56375813601778

# %%
#Proportion of left hands in the contralateral field during dynamic object interaction, in right handers
(dfPo[' portable_left_contra'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 15.436241863982216

# %%
#Proportion of left hands in the upper left quadrant during dynamic object interaction, in right handers
(dfPo[' portable_left_ULquad'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 18.941056922456646

# %%
#Proportion of left hands in the lower left quadrant during dynamic object interaction, in right handers
(dfPo[' portable_left_LLquad'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 65.62270121356114

# %%
#Proportion of left hands in the upper right quadrant during dynamic object interaction, in right handers
(dfPo[' portable_left_URquad'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 3.4248769562619534

# %%
#Proportion of left hands in the lower right quadrant during dynamic object interaction, in right handers
(dfPo[' portable_left_LRquad'].sum() / dfPo[' portable_left'].sum()) * 100
# Out:
# 12.011364907720262

# %% [markdown]
# ##Right handers - Portable objects - Right hand

# %%
#Proportion of right hands in the UVF during dynamic object interaction, in right handers
(dfPo[' portablet_right_upper'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 26.586219058623044

# %%
#Proportion of right hands in the LVF during dynamic object interaction, in right handers
(dfPo[' portable_right_lower'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 73.41378094137696

# %%
#Proportion of right hands in the ipsilateral field during dynamic object interaction, in right handers
(dfPo[' portable_right_ipsi'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 91.61610795642359

# %%
#Proportion of right hands in the contralateral field during dynamic object interaction, in right handers
(dfPo[' portable_right_contra'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 8.383892043576411

# %%
#Proportion of right hands in the upper left quadrant during dynamic object interaction, in right handers
(dfPo[' portable_right_ULquad'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 1.7680894697048761

# %%
#Proportion of right hands in the lower left quadrant during dynamic object interaction, in right handers
(dfPo[' portable_right_LLquad'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 6.6158025738715365

# %%
#Proportion of right hands in the upper right quadrant during dynamic object interaction, in right handers
(dfPo[' portable_right_URquad'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 24.81812958891817

# %%
#Proportion of right hands in the lower right quadrant during dynamic object interaction, in right handers
(dfPo[' portable_right_LRquad'].sum() / dfPo[' portable_hands_right'].sum()) * 100
# Out:
# 66.79797836750542

# %% [markdown]
# ##Right handers - Stationary objects - Irespective of hand side

# %%
#Loading the respective csv file
dfSt = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/rightHander_Stationary.csv')
dfSt
# Out:
#    hands_total   Stationary_total   Stationary_left   Stationary_left_upper  \
# 0     26966886             734673            360784                   91293
#
#     Stationary_left_lower   Stationary_left_ipsi   Stationary_left_contra  \
# 0                  269491                 312771                    48013
#
#     Stationary_left_ULquad   Stationary_left_LLquad   Stationary_left_URquad  \
# 0                    80091                   232680                    11202
#
#     Stationary_left_LRquad   Stationary_hands_right   Stationary_right_upper  \
# 0                    36811                   373889                   133673
#
#     Stationary_right_lower   Stationary_right_contra   Stationary_right_ipsi  \
# 0                   240216                     44744                  329145
#
#     Stationary_right_ULquad   Stationary_right_LLquad  \
# 0                     13654                     31090
#
#     Stationary_right_URquad   Stationary_right_LRquad
# ...

# %%
#Proportion of hands during stationary object interaction, in right handers
(dfSt[' Stationary_total'].sum() / dfSt['hands_total'].sum()) * 100
# Out:
# 2.7243523779497565

# %%
#Proportion of hands in the UVF during stationary object interaction, in right handers
((dfSt[' Stationary_left_upper'].sum() + dfSt[' Stationary_right_upper'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 30.621242375859737

# %%
#Proportion of hands in the LVF during stationary object interaction, in right handers
((dfSt[' Stationary_left_lower'].sum() + dfSt[' Stationary_right_lower'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 69.37875762414026

# %%
#Proportion of hands in the ipsilateral field during stationary object interaction, in right handers
((dfSt[' Stationary_left_ipsi'].sum() + dfSt[' Stationary_right_ipsi'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 87.37438288871375

# %%
#Proportion of hands in the contrlateral field during stationary object interaction, in right handers
((dfSt[' Stationary_left_contra'].sum() + dfSt[' Stationary_right_contra'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 12.625617111286246

# %%
#Proportion of hands in the upper left quadrant during stationary object interaction, in right handers
((dfSt[' Stationary_left_ULquad'].sum() + dfSt[' Stationary_right_ULquad'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 12.760098710582804

# %%
#Proportion of hands in the lower left quadrant during stationary object interaction, in right handers
((dfSt[' Stationary_left_LLquad'].sum() + dfSt[' Stationary_right_LLquad'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 35.903048022725756

# %%
#Proportion of hands in the upper right quadrant during stationary object interaction, in right handers
((dfSt[' Stationary_left_URquad'].sum() + dfSt[' Stationary_right_URquad'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 17.86114366527693

# %%
#Proportion of hands in the lower right quadrant during stationary object interaction, in right handers
((dfSt[' Stationary_left_LRquad'].sum() + dfSt[' Stationary_right_LRquad'].sum()) / dfSt[' Stationary_total'].sum()) * 100
# Out:
# 33.47570960141451

# %% [markdown]
# ##Right handers - Stationary objects - Left hand

# %%
#Proportion of left hands in the UVF during stationary object interaction, in right handers
(dfSt[' Stationary_left_upper'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 25.304060047008736

# %%
#Proportion of left hands in the LVF during stationary object interaction, in right handers
(dfSt[' Stationary_left_lower'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 74.69593995299127

# %%
#Proportion of left hands in the ipsilateral field during stationary object interaction, in right handers
(dfSt[' Stationary_left_ipsi'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 86.69203734090203

# %%
#Proportion of left hands in the contralateral field during stationary object interaction, in right handers
(dfSt[' Stationary_left_contra'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 13.307962659097964

# %%
#Proportion of left hands in the upper left quadrant during stationary object interaction, in right handers
(dfSt[' Stationary_left_ULquad'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 22.19915517317841

# %%
#Proportion of left hands in the lower left quadrant during stationary object interaction, in right handers
(dfSt[' Stationary_left_LLquad'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 64.49288216772362

# %%
#Proportion of left hands in the upper right quadrant during stationary object interaction, in right handers
(dfSt[' Stationary_left_URquad'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 3.1049048738303253

# %%
#Proportion of left hands in the lower right quadrant during stationary object interaction, in right handers
(dfSt[' Stationary_left_LRquad'].sum() / dfSt[' Stationary_left'].sum()) * 100
# Out:
# 10.20305778526764

# %% [markdown]
# ##Right handers - Stationary objects - Right hand

# %%
#Proportion of right hands in the UVF during stationary object interaction, in right handers
(dfSt[' Stationary_right_upper'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 35.7520547542185

# %%
#Proportion of right hands in the LVF during stationary object interaction, in right handers
(dfSt[' Stationary_right_lower'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 64.2479452457815

# %%
#Proportion of right hands in the ipsilateral field during stationary object interaction, in right handers
(dfSt[' Stationary_right_ipsi'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 88.03281187732188

# %%
#Proportion of right hands in the contralateral field during stationary object interaction, in right handers
(dfSt[' Stationary_right_contra'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 11.967188122678122

# %%
#Proportion of right hands in the upper left quadrant during stationary object interaction, in right handers
(dfSt[' Stationary_right_ULquad'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 3.651885987552456

# %%
#Proportion of right hands in the lower left quadrant during stationary object interaction, in right handers
(dfSt[' Stationary_right_LLquad'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 8.315302135125666

# %%
#Proportion of right hands in the upper right quadrant during stationary object interaction, in right handers
(dfSt[' Stationary_right_URquad'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 32.100168766666044

# %%
#Proportion of right hands in the lower right quadrant during stationary object interaction, in right handers
(dfSt[' Stationary_right_LRquad'].sum() / dfSt[' Stationary_hands_right'].sum()) * 100
# Out:
# 55.93264311065583

# %% [markdown]
# ##Right handers - Hand-hand interaction - irrespective of hand side

# %%
#Loading the respective csv file
dfSe = pd.read_csv('/content/gdrive/MyDrive/HandVisualField_Paper/hands_big_Csv_4_analysis/rightHanders_self.csv')
dfSe
# Out:
#    hands_total   hands_Self_total   hands_Self_left   hands_Self_left_upper  \
# 0     26966886             325538            167799                   32960
#
#     hands_Self_left_lower   hands_Self_left_ipsi   hands_Self_left_contra  \
# 0                  134839                  98766                    69033
#
#     hands_Self_left_ULquad   hands_Self_left_LLquad   hands_Self_left_URquad  \
# 0                    21263                    77503                    11697
#
#     hands_Self_left_LRquad   hands_Self_hands_right   hands_Self_right_upper  \
# 0                    57336                   157739                    30779
#
#     hands_Self_right_lower   hands_Self_right_contra   hands_Self_right_ipsi  \
# 0                   126960                     43459                  114280
#
#     hands_Self_right_ULquad   hands_Self_right_LLquad  \
# 0                      8587                     34872
#
#     hands_Self_right_URquad   hands_Self_right_LRquad
# ...

# %%
#Proportion of hands during self-contact, in right handers
(dfSe[' hands_Self_total'].sum() / dfSe['hands_total'].sum()) * 100
# Out:
# 1.2071768316148925

# %%
#Proportion of hands in the UVF during self-contact, in right handers
((dfSe[' hands_Self_left_upper'].sum() + dfSe[' hands_Self_right_upper'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 19.579588250834004

# %%
#Proportion of hands in the LVF during self-contact, in right handers
((dfSe[' hands_Self_left_lower'].sum() + dfSe[' hands_Self_right_lower'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 80.42041174916599

# %%
#Proportion of hands in the ipsilateral field during self-contact, in right handers
((dfSe[' hands_Self_left_ipsi'].sum() + dfSe[' hands_Self_right_ipsi'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 65.44427993045359

# %%
#Proportion of hands in the contralateral field during self-contact, in right handers
((dfSe[' hands_Self_left_contra'].sum() + dfSe[' hands_Self_right_contra'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 34.55572006954641

# %%
#Proportion of hands in the upper left quadrant during self-contact, in right handers
((dfSe[' hands_Self_left_ULquad'].sum() + dfSe[' hands_Self_right_ULquad'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 9.169436440599869

# %%
#Proportion of hands in the lower left quadrant during self-contact, in right handers
((dfSe[' hands_Self_left_LLquad'].sum() + dfSe[' hands_Self_right_LLquad'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 34.519779564904866

# %%
#Proportion of hands in the upper right quadrant during self-contact, in right handers
((dfSe[' hands_Self_left_URquad'].sum() + dfSe[' hands_Self_right_URquad'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 10.410151810234137

# %%
#Proportion of hands in the lower right quadrant during self-contact, in right handers
((dfSe[' hands_Self_left_LRquad'].sum() + dfSe[' hands_Self_right_LRquad'].sum()) / dfSe[' hands_Self_total'].sum()) * 100
# Out:
# 45.900632184261134

# %% [markdown]
# ##Right handers - Hand-hand interaction - Left hand

# %%
#Proportion of left hands in the lower right quadrant during self-contact, in right handers
(dfSe[' hands_Self_left_LRquad'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 34.16945273809737

# %%
#Proportion of left hands in the lower left quadrant during self-contact, in right handers
(dfSe[' hands_Self_left_LLquad'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 46.18799873658365

# %%
#Proportion of left hands in the upper right quadrant during self-contact, in right handers
(dfSe[' hands_Self_left_URquad'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 6.970840112277189

# %%
#Proportion of left hands in the upper left quadrant during self-contact, in right handers
(dfSe[' hands_Self_left_ULquad'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 12.671708413041793

# %%
#Proportion of left hands in the contralateral field during self-contact, in right handers
(dfSe[' hands_Self_left_contra'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 41.14029285037456

# %%
#Proportion of left hands in ipsilateral field during self-contact, in right handers
(dfSe[' hands_Self_left_ipsi'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 58.85970714962544

# %%
#Proportion of left hands in the LVF during self-contact, in right handers
(dfSe[' hands_Self_left_lower'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 80.35745147468101

# %%
#Proportion of left hands in the UVF during self-contact, in right handers
(dfSe[' hands_Self_left_upper'].sum() / dfSe[' hands_Self_left'].sum()) * 100
# Out:
# 19.642548525318983

# %% [markdown]
# ##Right handers - Hand-hand interaction - Right hand

# %%
#Proportion of right hands in the UVF during self-contact, in right handers
(dfSe[' hands_Self_right_upper'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 19.51261260690127

# %%
#Proportion of right hands in the LVF during self-contact, in right handers
(dfSe[' hands_Self_right_lower'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 80.48738739309873

# %%
#Proportion of right hands in the ipsilateral field during self-contact, in right handers
(dfSe[' hands_Self_right_ipsi'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 72.44879199183461

# %%
#Proportion of right hands in the contralateral field during self-contact, in right handers
(dfSe[' hands_Self_right_contra'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 27.55120800816539

# %%
#Proportion of right hands in the upper left quadrant during self-contact, in right handers
(dfSe[' hands_Self_right_ULquad'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 5.443802737433355

# %%
#Proportion of right hands in the lower left quadrant during self-contact, in right handers
(dfSe[' hands_Self_right_LLquad'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 22.10740527073203

# %%
#Proportion of right hands in the upper right quadrant during self-contact, in right handers
(dfSe[' hands_Self_right_URquad'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 14.068809869467918

# %%
#Proportion of right hands in the lower right quadrant during self-contact, in right handers
(dfSe[' hands_Self_right_LRquad'].sum() / dfSe[' hands_Self_hands_right'].sum()) * 100
# Out:
# 58.37998212236669

# %% [markdown]
# ---

# %%
# Install libraries to create the PDF
# %%capture
# !apt update
# !apt install texlive-xetex texlive-fonts-recommended texlive-generic-recommended

# %%
# Change to the drive we created above
# %cd #your destiny folder

# %%
#Exports the jupyter notebook to pdf
# !jupyter nbconvert VisualField_Methods_Proportions.ipynb --to pdf --output ./VisualField_Methods_Proportions.pdf
# Out:
# [NbConvertApp] Converting notebook VisualField_Methods_Proportions.ipynb to pdf
# [NbConvertApp] Writing 422366 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', './notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', './notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 214157 bytes to ./VisualField_Methods_Proportions.pdf
